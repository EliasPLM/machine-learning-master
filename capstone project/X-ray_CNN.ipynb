# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# Set path for datasets.
trainPath = 'balanced_chest_xray/Train'
valPath = 'balanced_chest_xray/Val'
testPath = 'balanced_chest_xray/Test'
originaltestPath = 'chest_xray/test'

# Applying data augmentation on training set.
print('Data in balanced data set')
trainGen = ImageDataGenerator(rotation_range=10 ,height_shift_range=0.2, width_shift_range=0.2, horizontal_flip=True)

# Preprosses the images in 128x128 grayscale in to batches.
trainBatch = trainGen.flow_from_directory(trainPath, target_size=(64,64), classes=['Pneumonia', 'Normal'], color_mode="grayscale", batch_size=16, shuffle=True)
vaildBatch = ImageDataGenerator().flow_from_directory(valPath, target_size=(64,64), classes=['Pneumonia', 'Normal'], color_mode="grayscale", batch_size=1, shuffle=False)
testBatch = ImageDataGenerator().flow_from_directory(testPath, target_size=(64,64), classes=['Pneumonia', 'Normal'], color_mode="grayscale", batch_size=1, shuffle=False)

# Preprosses the original test set in 128x128 grayscale in to batches.
print('\nOriginal test set')
testBatch_OG = ImageDataGenerator().flow_from_directory(originaltestPath, target_size=(64,64), classes=['Pneumonia', 'Normal'], color_mode="grayscale", batch_size=1, shuffle=False)


# Show the new label incoding
testBatch.class_indices
# Out:
# Data in balanced data set
# Found 2232 images belonging to 2 classes.
# Found 466 images belonging to 2 classes.
# Found 468 images belonging to 2 classes.
#
# Original test set
# Found 624 images belonging to 2 classes.
# {'Normal': 1, 'Pneumonia': 0}

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential

# Defining the model structure.
model = Sequential()

model.add(Conv2D(32, (3,3), strides=(1,1), padding='same', input_shape=(64,64,1), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 1,181,794
# Trainable params: 1,180,834
# Non-trainable params: 960
# _________________________________________________________________

# %%
# Compiling the model with Adam optimizer and cross entropy for loss measurement.
model.compile('Adam',loss="binary_crossentropy", metrics=["accuracy"])

# %%
from keras.callbacks import ModelCheckpoint, TensorBoard

# fitting the model to the training and validation set with modelcheckpoint function to save the best weights.
epoch=100
checkPoint = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', verbose=1, save_best_only=True, monitor='val_loss')


model.fit_generator(trainBatch, steps_per_epoch=155, validation_data=vaildBatch, validation_steps=len(vaildBatch), callbacks=[checkPoint], epochs=epoch)
# Out:
# Epoch 1/100
# 155/155 [==============================] - 19s 121ms/step - loss: 0.4134 - acc: 0.8689 - val_loss: 6.8742 - val_acc: 0.5000
#
# Epoch 00001: val_loss improved from inf to 6.87422, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.2808 - acc: 0.8903 - val_loss: 0.3805 - val_acc: 0.8455
#
# Epoch 00002: val_loss improved from 6.87422 to 0.38052, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 3/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.2097 - acc: 0.9153 - val_loss: 2.2194 - val_acc: 0.5794
#
# Epoch 00003: val_loss did not improve from 0.38052
# Epoch 4/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.2429 - acc: 0.9069 - val_loss: 1.9196 - val_acc: 0.5343
#
# Epoch 00004: val_loss did not improve from 0.38052
# Epoch 5/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.2075 - acc: 0.9218 - val_loss: 0.1932 - val_acc: 0.9163
#
# Epoch 00005: val_loss improved from 0.38052 to 0.19318, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 6/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.1953 - acc: 0.9169 - val_loss: 0.3198 - val_acc: 0.8777
#
# Epoch 00006: val_loss did not improve from 0.19318
# Epoch 7/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.1776 - acc: 0.9323 - val_loss: 3.7508 - val_acc: 0.5043
#
# Epoch 00007: val_loss did not improve from 0.19318
# Epoch 8/100
# 155/155 [==============================] - 17s 110ms/step - loss: 0.1575 - acc: 0.9448 - val_loss: 0.1656 - val_acc: 0.9399
#
# Epoch 00008: val_loss improved from 0.19318 to 0.16555, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 9/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.1535 - acc: 0.9460 - val_loss: 0.4589 - val_acc: 0.8498
#
# Epoch 00009: val_loss did not improve from 0.16555
# Epoch 10/100
# 155/155 [==============================] - 18s 116ms/step - loss: 0.1627 - acc: 0.9391 - val_loss: 1.0188 - val_acc: 0.6738
#
# Epoch 00010: val_loss did not improve from 0.16555
# Epoch 11/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.1508 - acc: 0.9448 - val_loss: 0.3962 - val_acc: 0.8348
#
# Epoch 00011: val_loss did not improve from 0.16555
# Epoch 12/100
# 155/155 [==============================] - 18s 117ms/step - loss: 0.1391 - acc: 0.9520 - val_loss: 0.2504 - val_acc: 0.8906
#
# Epoch 00012: val_loss did not improve from 0.16555
# Epoch 13/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.1588 - acc: 0.9427 - val_loss: 2.6262 - val_acc: 0.5601
#
# Epoch 00013: val_loss did not improve from 0.16555
# Epoch 14/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.1326 - acc: 0.9496 - val_loss: 0.1499 - val_acc: 0.9528
#
# Epoch 00014: val_loss improved from 0.16555 to 0.14986, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 15/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.1401 - acc: 0.9435 - val_loss: 1.0691 - val_acc: 0.6438
#
# Epoch 00015: val_loss did not improve from 0.14986
# Epoch 16/100
# 155/155 [==============================] - 17s 110ms/step - loss: 0.1234 - acc: 0.9528 - val_loss: 0.2421 - val_acc: 0.9099
#
# Epoch 00016: val_loss did not improve from 0.14986
# Epoch 17/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.1336 - acc: 0.9488 - val_loss: 0.1684 - val_acc: 0.9313
#
# Epoch 00017: val_loss did not improve from 0.14986
# Epoch 18/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.1184 - acc: 0.9556 - val_loss: 0.3198 - val_acc: 0.8863
#
# Epoch 00018: val_loss did not improve from 0.14986
# Epoch 19/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.1120 - acc: 0.9589 - val_loss: 0.6991 - val_acc: 0.7876
#
# Epoch 00019: val_loss did not improve from 0.14986
# Epoch 20/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.1169 - acc: 0.9605 - val_loss: 0.1561 - val_acc: 0.9335
#
# Epoch 00020: val_loss did not improve from 0.14986
# Epoch 21/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.1016 - acc: 0.9649 - val_loss: 0.1649 - val_acc: 0.9335
#
# Epoch 00021: val_loss did not improve from 0.14986
# Epoch 22/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.1048 - acc: 0.9617 - val_loss: 0.0917 - val_acc: 0.9678
#
# Epoch 00022: val_loss improved from 0.14986 to 0.09167, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 23/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.1118 - acc: 0.9601 - val_loss: 1.5522 - val_acc: 0.6824
#
# Epoch 00023: val_loss did not improve from 0.09167
# Epoch 24/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0970 - acc: 0.9625 - val_loss: 0.4177 - val_acc: 0.8670
#
# Epoch 00024: val_loss did not improve from 0.09167
# Epoch 25/100
# 155/155 [==============================] - 18s 118ms/step - loss: 0.1111 - acc: 0.9613 - val_loss: 0.1779 - val_acc: 0.9442
#
# Epoch 00025: val_loss did not improve from 0.09167
# Epoch 26/100
# 155/155 [==============================] - 18s 117ms/step - loss: 0.0934 - acc: 0.9657 - val_loss: 0.1297 - val_acc: 0.9335
#
# Epoch 00026: val_loss did not improve from 0.09167
# Epoch 27/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0798 - acc: 0.9730 - val_loss: 0.1207 - val_acc: 0.9442
#
# Epoch 00027: val_loss did not improve from 0.09167
# Epoch 28/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0967 - acc: 0.9685 - val_loss: 0.1056 - val_acc: 0.9635
#
# Epoch 00028: val_loss did not improve from 0.09167
# Epoch 29/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0806 - acc: 0.9669 - val_loss: 0.1159 - val_acc: 0.9657
#
# Epoch 00029: val_loss did not improve from 0.09167
# Epoch 30/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0921 - acc: 0.9625 - val_loss: 1.3597 - val_acc: 0.7983
#
# Epoch 00030: val_loss did not improve from 0.09167
# Epoch 31/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0955 - acc: 0.9629 - val_loss: 0.1676 - val_acc: 0.9356
#
# Epoch 00031: val_loss did not improve from 0.09167
# Epoch 32/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0944 - acc: 0.9649 - val_loss: 0.1431 - val_acc: 0.9378
#
# Epoch 00032: val_loss did not improve from 0.09167
# Epoch 33/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0755 - acc: 0.9702 - val_loss: 0.1364 - val_acc: 0.9399
#
# Epoch 00033: val_loss did not improve from 0.09167
# Epoch 34/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0841 - acc: 0.9669 - val_loss: 0.5141 - val_acc: 0.7811
#
# Epoch 00034: val_loss did not improve from 0.09167
# Epoch 35/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0551 - acc: 0.9794 - val_loss: 3.3224 - val_acc: 0.5279
#
# Epoch 00035: val_loss did not improve from 0.09167
# Epoch 36/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0816 - acc: 0.9694 - val_loss: 0.1256 - val_acc: 0.9571
#
# Epoch 00036: val_loss did not improve from 0.09167
# Epoch 37/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0809 - acc: 0.9706 - val_loss: 0.4675 - val_acc: 0.8155
#
# Epoch 00037: val_loss did not improve from 0.09167
# Epoch 38/100
# 155/155 [==============================] - 18s 116ms/step - loss: 0.0800 - acc: 0.9714 - val_loss: 0.1026 - val_acc: 0.9678
#
# Epoch 00038: val_loss did not improve from 0.09167
# Epoch 39/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0837 - acc: 0.9665 - val_loss: 0.1253 - val_acc: 0.9549
#
# Epoch 00039: val_loss did not improve from 0.09167
# Epoch 40/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0716 - acc: 0.9718 - val_loss: 0.1541 - val_acc: 0.9442
#
# Epoch 00040: val_loss did not improve from 0.09167
# Epoch 41/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0702 - acc: 0.9746 - val_loss: 3.1596 - val_acc: 0.5043
#
# Epoch 00041: val_loss did not improve from 0.09167
# Epoch 42/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0906 - acc: 0.9681 - val_loss: 0.3996 - val_acc: 0.8670
#
# Epoch 00042: val_loss did not improve from 0.09167
# Epoch 43/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0803 - acc: 0.9702 - val_loss: 0.9132 - val_acc: 0.6717
#
# Epoch 00043: val_loss did not improve from 0.09167
# Epoch 44/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0687 - acc: 0.9750 - val_loss: 0.3755 - val_acc: 0.8991
#
# Epoch 00044: val_loss did not improve from 0.09167
# Epoch 45/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0656 - acc: 0.9790 - val_loss: 0.0776 - val_acc: 0.9700
#
# Epoch 00045: val_loss improved from 0.09167 to 0.07763, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 46/100
# 155/155 [==============================] - 18s 117ms/step - loss: 0.0734 - acc: 0.9742 - val_loss: 0.3818 - val_acc: 0.8820
#
# Epoch 00046: val_loss did not improve from 0.07763
# Epoch 47/100
# 155/155 [==============================] - 18s 116ms/step - loss: 0.0852 - acc: 0.9665 - val_loss: 0.2849 - val_acc: 0.8884
#
# Epoch 00047: val_loss did not improve from 0.07763
# Epoch 48/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0711 - acc: 0.9750 - val_loss: 0.0882 - val_acc: 0.9721
#
# Epoch 00048: val_loss did not improve from 0.07763
# Epoch 49/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0515 - acc: 0.9823 - val_loss: 0.0447 - val_acc: 0.9807
#
# Epoch 00049: val_loss improved from 0.07763 to 0.04465, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 50/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0606 - acc: 0.9754 - val_loss: 0.5273 - val_acc: 0.8476
#
# Epoch 00050: val_loss did not improve from 0.04465
# Epoch 51/100
# 155/155 [==============================] - 18s 116ms/step - loss: 0.0733 - acc: 0.9730 - val_loss: 0.1594 - val_acc: 0.9592
#
# Epoch 00051: val_loss did not improve from 0.04465
# Epoch 52/100
# 155/155 [==============================] - 20s 126ms/step - loss: 0.0578 - acc: 0.9786 - val_loss: 0.0468 - val_acc: 0.9764
#
# Epoch 00052: val_loss did not improve from 0.04465
# Epoch 53/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0609 - acc: 0.9750 - val_loss: 0.2078 - val_acc: 0.9464
#
# Epoch 00053: val_loss did not improve from 0.04465
# Epoch 54/100
# 155/155 [==============================] - 18s 115ms/step - loss: 0.0588 - acc: 0.9766 - val_loss: 0.2110 - val_acc: 0.9356
#
# Epoch 00054: val_loss did not improve from 0.04465
# Epoch 55/100
# 155/155 [==============================] - 18s 115ms/step - loss: 0.0784 - acc: 0.9718 - val_loss: 0.1340 - val_acc: 0.9614
#
# Epoch 00055: val_loss did not improve from 0.04465
# Epoch 56/100
# 155/155 [==============================] - 18s 115ms/step - loss: 0.0627 - acc: 0.9758 - val_loss: 0.8904 - val_acc: 0.7489
#
# Epoch 00056: val_loss did not improve from 0.04465
# Epoch 57/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0517 - acc: 0.9847 - val_loss: 0.7049 - val_acc: 0.8090
#
# Epoch 00057: val_loss did not improve from 0.04465
# Epoch 58/100
# 155/155 [==============================] - 18s 117ms/step - loss: 0.0631 - acc: 0.9762 - val_loss: 0.7907 - val_acc: 0.7876
#
# Epoch 00058: val_loss did not improve from 0.04465
# Epoch 59/100
# 155/155 [==============================] - 18s 115ms/step - loss: 0.0474 - acc: 0.9819 - val_loss: 0.1054 - val_acc: 0.9571
#
# Epoch 00059: val_loss did not improve from 0.04465
# Epoch 60/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0539 - acc: 0.9811 - val_loss: 0.0583 - val_acc: 0.9785
#
# Epoch 00060: val_loss did not improve from 0.04465
# Epoch 61/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0537 - acc: 0.9802 - val_loss: 0.1220 - val_acc: 0.9657
#
# Epoch 00061: val_loss did not improve from 0.04465
# Epoch 62/100
# 155/155 [==============================] - 18s 116ms/step - loss: 0.0484 - acc: 0.9810 - val_loss: 0.3711 - val_acc: 0.8584
#
# Epoch 00062: val_loss did not improve from 0.04465
# Epoch 63/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0578 - acc: 0.9794 - val_loss: 0.0871 - val_acc: 0.9678
#
# Epoch 00063: val_loss did not improve from 0.04465
# Epoch 64/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0370 - acc: 0.9847 - val_loss: 0.0916 - val_acc: 0.9764
#
# Epoch 00064: val_loss did not improve from 0.04465
# Epoch 65/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0610 - acc: 0.9794 - val_loss: 0.1071 - val_acc: 0.9700
#
# Epoch 00065: val_loss did not improve from 0.04465
# Epoch 66/100
# 155/155 [==============================] - 18s 118ms/step - loss: 0.0432 - acc: 0.9847 - val_loss: 0.0366 - val_acc: 0.9828
#
# Epoch 00066: val_loss improved from 0.04465 to 0.03662, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 67/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0430 - acc: 0.9831 - val_loss: 0.2560 - val_acc: 0.8991
#
# Epoch 00067: val_loss did not improve from 0.03662
# Epoch 68/100
# 155/155 [==============================] - 18s 116ms/step - loss: 0.0761 - acc: 0.9730 - val_loss: 0.3939 - val_acc: 0.8841
#
# Epoch 00068: val_loss did not improve from 0.03662
# Epoch 69/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0679 - acc: 0.9770 - val_loss: 0.2460 - val_acc: 0.9313
#
# Epoch 00069: val_loss did not improve from 0.03662
# Epoch 70/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0318 - acc: 0.9855 - val_loss: 0.2036 - val_acc: 0.9227
#
# Epoch 00070: val_loss did not improve from 0.03662
# Epoch 71/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0404 - acc: 0.9863 - val_loss: 0.1505 - val_acc: 0.9356
#
# Epoch 00071: val_loss did not improve from 0.03662
# Epoch 72/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0643 - acc: 0.9778 - val_loss: 0.1212 - val_acc: 0.9549
#
# Epoch 00072: val_loss did not improve from 0.03662
# Epoch 73/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0526 - acc: 0.9794 - val_loss: 0.0595 - val_acc: 0.9700
#
# Epoch 00073: val_loss did not improve from 0.03662
# Epoch 74/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0588 - acc: 0.9778 - val_loss: 1.2917 - val_acc: 0.8004
#
# Epoch 00074: val_loss did not improve from 0.03662
# Epoch 75/100
# 155/155 [==============================] - 18s 115ms/step - loss: 0.0556 - acc: 0.9762 - val_loss: 0.4792 - val_acc: 0.9099
#
# Epoch 00075: val_loss did not improve from 0.03662
# Epoch 76/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0533 - acc: 0.9819 - val_loss: 0.1082 - val_acc: 0.9700
#
# Epoch 00076: val_loss did not improve from 0.03662
# Epoch 77/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0485 - acc: 0.9802 - val_loss: 0.6999 - val_acc: 0.8562
#
# Epoch 00077: val_loss did not improve from 0.03662
# Epoch 78/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0403 - acc: 0.9851 - val_loss: 0.1940 - val_acc: 0.9464
#
# Epoch 00078: val_loss did not improve from 0.03662
# Epoch 79/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0426 - acc: 0.9863 - val_loss: 1.3949 - val_acc: 0.6631
#
# Epoch 00079: val_loss did not improve from 0.03662
# Epoch 80/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0488 - acc: 0.9815 - val_loss: 0.2510 - val_acc: 0.9506
#
# Epoch 00080: val_loss did not improve from 0.03662
# Epoch 81/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0456 - acc: 0.9839 - val_loss: 0.0882 - val_acc: 0.9764
#
# Epoch 00081: val_loss did not improve from 0.03662
# Epoch 82/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0376 - acc: 0.9843 - val_loss: 0.1454 - val_acc: 0.9657
#
# Epoch 00082: val_loss did not improve from 0.03662
# Epoch 83/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0528 - acc: 0.9794 - val_loss: 0.3286 - val_acc: 0.9206
#
# Epoch 00083: val_loss did not improve from 0.03662
# Epoch 84/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0293 - acc: 0.9891 - val_loss: 0.1701 - val_acc: 0.9528
#
# Epoch 00084: val_loss did not improve from 0.03662
# Epoch 85/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0471 - acc: 0.9810 - val_loss: 0.1060 - val_acc: 0.9635
#
# Epoch 00085: val_loss did not improve from 0.03662
# Epoch 86/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0406 - acc: 0.9843 - val_loss: 0.1903 - val_acc: 0.9399
#
# Epoch 00086: val_loss did not improve from 0.03662
# Epoch 87/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0472 - acc: 0.9823 - val_loss: 0.0523 - val_acc: 0.9785
#
# Epoch 00087: val_loss did not improve from 0.03662
# Epoch 88/100
# 155/155 [==============================] - 17s 110ms/step - loss: 0.0327 - acc: 0.9891 - val_loss: 0.0728 - val_acc: 0.9871
#
# Epoch 00088: val_loss did not improve from 0.03662
# Epoch 89/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0333 - acc: 0.9875 - val_loss: 0.1666 - val_acc: 0.9571
#
# Epoch 00089: val_loss did not improve from 0.03662
# Epoch 90/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0341 - acc: 0.9879 - val_loss: 0.0494 - val_acc: 0.9850
#
# Epoch 00090: val_loss did not improve from 0.03662
# Epoch 91/100
# 155/155 [==============================] - 18s 114ms/step - loss: 0.0315 - acc: 0.9879 - val_loss: 0.0923 - val_acc: 0.9678
#
# Epoch 00091: val_loss did not improve from 0.03662
# Epoch 92/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0462 - acc: 0.9847 - val_loss: 0.1119 - val_acc: 0.9549
#
# Epoch 00092: val_loss did not improve from 0.03662
# Epoch 93/100
# 155/155 [==============================] - 17s 111ms/step - loss: 0.0408 - acc: 0.9875 - val_loss: 0.3319 - val_acc: 0.9378
#
# Epoch 00093: val_loss did not improve from 0.03662
# Epoch 94/100
# 155/155 [==============================] - 18s 117ms/step - loss: 0.0346 - acc: 0.9871 - val_loss: 0.0868 - val_acc: 0.9721
#
# Epoch 00094: val_loss did not improve from 0.03662
# Epoch 95/100
# 155/155 [==============================] - 18s 115ms/step - loss: 0.0445 - acc: 0.9851 - val_loss: 0.1180 - val_acc: 0.9721
#
# Epoch 00095: val_loss did not improve from 0.03662
# Epoch 96/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0249 - acc: 0.9911 - val_loss: 0.0424 - val_acc: 0.9893
#
# Epoch 00096: val_loss did not improve from 0.03662
# Epoch 97/100
# 155/155 [==============================] - 17s 113ms/step - loss: 0.0240 - acc: 0.9899 - val_loss: 3.0702 - val_acc: 0.7017
#
# Epoch 00097: val_loss did not improve from 0.03662
# Epoch 98/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0357 - acc: 0.9859 - val_loss: 0.1272 - val_acc: 0.9592
#
# Epoch 00098: val_loss did not improve from 0.03662
# Epoch 99/100
# 155/155 [==============================] - 17s 112ms/step - loss: 0.0374 - acc: 0.9867 - val_loss: 0.1795 - val_acc: 0.9464
#
# Epoch 00099: val_loss did not improve from 0.03662
# Epoch 100/100
# 155/155 [==============================] - 18s 113ms/step - loss: 0.0266 - acc: 0.9923 - val_loss: 0.1507 - val_acc: 0.9506
#
# Epoch 00100: val_loss did not improve from 0.03662

# %%
# Evalutate the model and show loss and accuracy.
loss, acc = model.evaluate_generator(testBatch, steps=len(testBatch))

print('model performancens on balance data')
print('loss:{}'.format(loss) )
print('accuracy:{}'.format(acc))
# Out:
# model performancens on balance data
# loss:2.079278032891692
# accuracy:0.6901709401709402

# %%
# loding the model from the checkpoint function to get the best weights based on validation set loss.
model.load_weights('saved_models/weights.best.from_scratch.hdf5')
print('Best weights are loaded')
# Out:
# Best weights are loaded

# %%
# Evalutate the model and show loss and accuracy with best weights
loss, acc = model.evaluate_generator(testBatch, steps=len(testBatch))

print('model performancens on balance data with best weights')
print('loss:{}'.format(loss) )
print('accuracy:{}'.format(acc))
# Out:
# model performancens on balance data with best weights
# loss:0.4747115498066599
# accuracy:0.8803418803418803

# %%
# Making prediction on balanced test set and the original
pred = model.predict_generator(testBatch, steps=len(testBatch), verbose=True)
pred_OG = model.predict_generator(testBatch_OG, steps=len(testBatch_OG), verbose=True)
# Out:
# 468/468 [==============================] - 2s 4ms/step
# 624/624 [==============================] - 2s 4ms/step

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import fbeta_score
import numpy as np

# Preprocess the predicted test set and it predcitons for y true and y predict
def Preprocess_yTrue_yPred(predict, testset):
    # Round the prediced data from test set to 1 and 0 for each class(True, False)
    pred = np.rint(predict)
    # Making y true variable with label(Normal: 0, Pneumonia: 1)
    y_true = testset.classes
    
    # Making y predict variable with appendig all Pneumonia predciton(Pneumonia True: 1, Pneumonia False: 0)
    y_pred = []
    for normal, Pneumonia in pred:
        y_pred.append(Pneumonia)
   
    # returning Y true and Y predict
    return y_true, y_pred

# Show all the metrics(accuracy, precision, recall and fbeta score) for input y_True and y_predict
def Metrics_results(y_true, y_pred):
    # Initializing all metricis for benchmarking
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    
    # priting resualts
    fbeta = fbeta_score(y_true, y_pred, average='macro', beta=2)
    # Prnit benchmark resualts for test set
    print('Accuracy:{}'.format(accuracy))
    print('Precision:{}'.format(precision))
    print('Recall:{}'.format(recall))
    print('Fbeta score:{}'.format(fbeta))

# %%
# Applaying Preprocess function to balance test set and predcit
y_true, y_pred = Preprocess_yTrue_yPred(pred, testBatch)
# Applaying Preprocess function to original test set and predcit
y_true_OG, y_pred_OG = Preprocess_yTrue_yPred(pred_OG, testBatch_OG)

#print benmark results for balance test set
print('Benmark for balance test set')
Metrics_results(y_true, y_pred)

#print benmark results for original test set
print('\nBenmark for original test set')
Metrics_results(y_true_OG, y_pred_OG)
# Out:
# Benmark for balance test set
# Accuracy:0.8803418803418803
# Precision:0.8739495798319328
# Recall:0.8888888888888888
# Fbeta score:0.8803229492053382
#
# Benmark for original test set
# Accuracy:0.8717948717948718
# Precision:0.7938931297709924
# Recall:0.8888888888888888
# Fbeta score:0.8711015063260132
