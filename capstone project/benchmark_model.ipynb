# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# Set path for datasets.
trainPath = 'balanced_chest_xray/Train'
valPath = 'balanced_chest_xray/Val'
testPath = 'balanced_chest_xray/Test'
originaltestPath = 'chest_xray/test'

# Creating a generator for data augmentation for the training set.
print('Data in balanced data set')
trainGen = ImageDataGenerator(rotation_range=10 ,height_shift_range=0.2, width_shift_range=0.2, horizontal_flip=True)

# Preprosses the images in 128x128 grayscale in to batches.
trainBatch = trainGen.flow_from_directory(trainPath, target_size=(64,64), classes=['Pneumonia', 'Normal'], color_mode="grayscale", batch_size=16, shuffle=True)
vaildBatch = ImageDataGenerator().flow_from_directory(valPath, target_size=(64,64), classes=['Pneumonia', 'Normal'], color_mode="grayscale", batch_size=1, shuffle=False)
testBatch = ImageDataGenerator().flow_from_directory(testPath, target_size=(64,64), classes=['Pneumonia', 'Normal'], color_mode="grayscale", batch_size=1, shuffle=False)

# Preprosses the original test set in 128x128 grayscale in to batches.
print('\nOriginal test set')
testBatch_OG = ImageDataGenerator().flow_from_directory(originaltestPath, target_size=(64,64), classes=['Pneumonia', 'Normal'], color_mode="grayscale", batch_size=1, shuffle=False)


# Show the new labels incoding.
testBatch.class_indices
# Out:
# Using TensorFlow backend.
# Data in balanced data set
# Found 2232 images belonging to 2 classes.
# Found 466 images belonging to 2 classes.
# Found 468 images belonging to 2 classes.
#
# Original test set
# Found 624 images belonging to 2 classes.
# {'Normal': 1, 'Pneumonia': 0}

# %%
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential

# Defining the model structure.
model = Sequential()
model.add(Conv2D(32, (3,3), strides=(1,1), padding='same', input_shape=(64,64,1), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(2, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 9,202,786
# Trainable params: 9,202,338
# Non-trainable params: 448
# _________________________________________________________________

# %%
# Compiling the model with Adam optimizer and cross entropy for loss measurement.
model.compile('Adam',loss="binary_crossentropy", metrics=["accuracy"])

# %%
from keras.callbacks import ModelCheckpoint

# fitting the model to the training and validation.
epoch=100
checkPoint = ModelCheckpoint(filepath='saved_model/weights.best.from_Benmark.hdf5', verbose=1, save_best_only=True, monitor='val_loss')
model.fit_generator(trainBatch, steps_per_epoch=155, validation_data=vaildBatch, validation_steps=len(vaildBatch), callbacks=[checkPoint], epochs=epoch)
# Out:
# Epoch 1/100
# 155/155 [==============================] - 31s 201ms/step - loss: 1.9369 - acc: 0.7218 - val_loss: 0.5922 - val_acc: 0.7403
#
# Epoch 00001: val_loss improved from inf to 0.59223, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 2/100
# 155/155 [==============================] - 31s 199ms/step - loss: 0.5467 - acc: 0.8056 - val_loss: 0.5268 - val_acc: 0.8841
#
# Epoch 00002: val_loss improved from 0.59223 to 0.52681, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 3/100
# 155/155 [==============================] - 30s 195ms/step - loss: 0.3394 - acc: 0.8689 - val_loss: 6.4151 - val_acc: 0.4979
#
# Epoch 00003: val_loss did not improve from 0.52681
# Epoch 4/100
# 155/155 [==============================] - 34s 222ms/step - loss: 0.3098 - acc: 0.8843 - val_loss: 0.6540 - val_acc: 0.5880
#
# Epoch 00004: val_loss did not improve from 0.52681
# Epoch 5/100
# 155/155 [==============================] - 32s 205ms/step - loss: 0.2666 - acc: 0.8964 - val_loss: 0.8900 - val_acc: 0.5000
#
# Epoch 00005: val_loss did not improve from 0.52681
# Epoch 6/100
# 155/155 [==============================] - 31s 199ms/step - loss: 0.2821 - acc: 0.9020 - val_loss: 0.7778 - val_acc: 0.5451
#
# Epoch 00006: val_loss did not improve from 0.52681
# Epoch 7/100
# 155/155 [==============================] - 31s 202ms/step - loss: 0.2630 - acc: 0.9165 - val_loss: 0.4350 - val_acc: 0.8906
#
# Epoch 00007: val_loss improved from 0.52681 to 0.43499, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 8/100
# 155/155 [==============================] - 30s 191ms/step - loss: 0.2386 - acc: 0.9117 - val_loss: 3.5375 - val_acc: 0.5000
#
# Epoch 00008: val_loss did not improve from 0.43499
# Epoch 9/100
# 155/155 [==============================] - 33s 211ms/step - loss: 0.2310 - acc: 0.9113 - val_loss: 0.2148 - val_acc: 0.9077
#
# Epoch 00009: val_loss improved from 0.43499 to 0.21477, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 10/100
# 155/155 [==============================] - 34s 219ms/step - loss: 0.2306 - acc: 0.9218 - val_loss: 0.5605 - val_acc: 0.5472
#
# Epoch 00010: val_loss did not improve from 0.21477
# Epoch 11/100
# 155/155 [==============================] - 33s 213ms/step - loss: 0.2022 - acc: 0.9270 - val_loss: 0.6161 - val_acc: 0.6416
#
# Epoch 00011: val_loss did not improve from 0.21477
# Epoch 12/100
# 155/155 [==============================] - 34s 217ms/step - loss: 0.2060 - acc: 0.9270 - val_loss: 1.4248 - val_acc: 0.5665
#
# Epoch 00012: val_loss did not improve from 0.21477
# Epoch 13/100
# 155/155 [==============================] - 33s 213ms/step - loss: 0.1850 - acc: 0.9298 - val_loss: 0.0944 - val_acc: 0.9721
#
# Epoch 00013: val_loss improved from 0.21477 to 0.09440, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 14/100
# 155/155 [==============================] - 33s 215ms/step - loss: 0.1710 - acc: 0.9427 - val_loss: 0.4455 - val_acc: 0.7918
#
# Epoch 00014: val_loss did not improve from 0.09440
# Epoch 15/100
# 155/155 [==============================] - 33s 215ms/step - loss: 0.1774 - acc: 0.9339 - val_loss: 0.3274 - val_acc: 0.8863
#
# Epoch 00015: val_loss did not improve from 0.09440
# Epoch 16/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1890 - acc: 0.9379 - val_loss: 0.7830 - val_acc: 0.6180
#
# Epoch 00016: val_loss did not improve from 0.09440
# Epoch 17/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1790 - acc: 0.9335 - val_loss: 0.2181 - val_acc: 0.9249
#
# Epoch 00017: val_loss did not improve from 0.09440
# Epoch 18/100
# 155/155 [==============================] - 34s 216ms/step - loss: 0.1762 - acc: 0.9391 - val_loss: 0.1570 - val_acc: 0.9270
#
# Epoch 00018: val_loss did not improve from 0.09440
# Epoch 19/100
# 155/155 [==============================] - 33s 216ms/step - loss: 0.1795 - acc: 0.9375 - val_loss: 0.4002 - val_acc: 0.8240
#
# Epoch 00019: val_loss did not improve from 0.09440
# Epoch 20/100
# 155/155 [==============================] - 33s 215ms/step - loss: 0.1864 - acc: 0.9351 - val_loss: 0.1074 - val_acc: 0.9571
#
# Epoch 00020: val_loss did not improve from 0.09440
# Epoch 21/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1553 - acc: 0.9480 - val_loss: 0.1851 - val_acc: 0.9013
#
# Epoch 00021: val_loss did not improve from 0.09440
# Epoch 22/100
# 155/155 [==============================] - 33s 216ms/step - loss: 0.1478 - acc: 0.9460 - val_loss: 0.5140 - val_acc: 0.8090
#
# Epoch 00022: val_loss did not improve from 0.09440
# Epoch 23/100
# 155/155 [==============================] - 35s 228ms/step - loss: 0.1521 - acc: 0.9444 - val_loss: 0.3607 - val_acc: 0.8262
#
# Epoch 00023: val_loss did not improve from 0.09440
# Epoch 24/100
# 155/155 [==============================] - 33s 215ms/step - loss: 0.1721 - acc: 0.9355 - val_loss: 0.2152 - val_acc: 0.9292
#
# Epoch 00024: val_loss did not improve from 0.09440
# Epoch 25/100
# 155/155 [==============================] - 34s 218ms/step - loss: 0.1279 - acc: 0.9548 - val_loss: 0.4895 - val_acc: 0.7361
#
# Epoch 00025: val_loss did not improve from 0.09440
# Epoch 26/100
# 155/155 [==============================] - 33s 213ms/step - loss: 0.1511 - acc: 0.9464 - val_loss: 0.1782 - val_acc: 0.9227
#
# Epoch 00026: val_loss did not improve from 0.09440
# Epoch 27/100
# 155/155 [==============================] - 33s 211ms/step - loss: 0.1345 - acc: 0.9520 - val_loss: 0.0965 - val_acc: 0.9657
#
# Epoch 00027: val_loss did not improve from 0.09440
# Epoch 28/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1247 - acc: 0.9496 - val_loss: 0.1932 - val_acc: 0.9206
#
# Epoch 00028: val_loss did not improve from 0.09440
# Epoch 29/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1435 - acc: 0.9504 - val_loss: 0.5706 - val_acc: 0.7403
#
# Epoch 00029: val_loss did not improve from 0.09440
# Epoch 30/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1447 - acc: 0.9488 - val_loss: 0.1554 - val_acc: 0.9356
#
# Epoch 00030: val_loss did not improve from 0.09440
# Epoch 31/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1285 - acc: 0.9520 - val_loss: 0.3458 - val_acc: 0.8519
#
# Epoch 00031: val_loss did not improve from 0.09440
# Epoch 32/100
# 155/155 [==============================] - 33s 216ms/step - loss: 0.1265 - acc: 0.9544 - val_loss: 0.1376 - val_acc: 0.9442
#
# Epoch 00032: val_loss did not improve from 0.09440
# Epoch 33/100
# 155/155 [==============================] - 33s 213ms/step - loss: 0.1444 - acc: 0.9500 - val_loss: 0.1862 - val_acc: 0.9227
#
# Epoch 00033: val_loss did not improve from 0.09440
# Epoch 34/100
# 155/155 [==============================] - 33s 210ms/step - loss: 0.1125 - acc: 0.9613 - val_loss: 0.9099 - val_acc: 0.7511
#
# Epoch 00034: val_loss did not improve from 0.09440
# Epoch 35/100
# 155/155 [==============================] - 34s 216ms/step - loss: 0.1377 - acc: 0.9552 - val_loss: 0.8838 - val_acc: 0.6545
#
# Epoch 00035: val_loss did not improve from 0.09440
# Epoch 36/100
# 155/155 [==============================] - 33s 213ms/step - loss: 0.1203 - acc: 0.9573 - val_loss: 0.5554 - val_acc: 0.6717
#
# Epoch 00036: val_loss did not improve from 0.09440
# Epoch 37/100
# 155/155 [==============================] - 34s 217ms/step - loss: 0.1150 - acc: 0.9565 - val_loss: 0.4951 - val_acc: 0.8391
#
# Epoch 00037: val_loss did not improve from 0.09440
# Epoch 38/100
# 155/155 [==============================] - 33s 213ms/step - loss: 0.1186 - acc: 0.9605 - val_loss: 0.1094 - val_acc: 0.9614
#
# Epoch 00038: val_loss did not improve from 0.09440
# Epoch 39/100
# 155/155 [==============================] - 33s 212ms/step - loss: 0.1347 - acc: 0.9496 - val_loss: 0.1013 - val_acc: 0.9614
#
# Epoch 00039: val_loss did not improve from 0.09440
# Epoch 40/100
# 155/155 [==============================] - 33s 215ms/step - loss: 0.1278 - acc: 0.9516 - val_loss: 0.3119 - val_acc: 0.8670
#
# Epoch 00040: val_loss did not improve from 0.09440
# Epoch 41/100
# 155/155 [==============================] - 33s 215ms/step - loss: 0.1273 - acc: 0.9556 - val_loss: 0.2005 - val_acc: 0.9185
#
# Epoch 00041: val_loss did not improve from 0.09440
# Epoch 42/100
# 155/155 [==============================] - 33s 213ms/step - loss: 0.1361 - acc: 0.9504 - val_loss: 0.2626 - val_acc: 0.8970
# Epoch 00042: val_loss did not improve from 0.09440
# Epoch 43/100
# 155/155 [==============================] - 32s 210ms/step - loss: 0.1037 - acc: 0.9609 - val_loss: 0.1387 - val_acc: 0.9464
#
# Epoch 00043: val_loss did not improve from 0.09440
# Epoch 44/100
# 155/155 [==============================] - 34s 216ms/step - loss: 0.1083 - acc: 0.9609 - val_loss: 0.2183 - val_acc: 0.9292
#
# Epoch 00044: val_loss did not improve from 0.09440
# Epoch 45/100
# 155/155 [==============================] - 33s 216ms/step - loss: 0.1132 - acc: 0.9605 - val_loss: 0.0925 - val_acc: 0.9678
#
# Epoch 00045: val_loss improved from 0.09440 to 0.09249, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 46/100
# 155/155 [==============================] - 34s 216ms/step - loss: 0.1173 - acc: 0.9609 - val_loss: 0.2469 - val_acc: 0.8970
#
# Epoch 00046: val_loss did not improve from 0.09249
# Epoch 47/100
# 155/155 [==============================] - 33s 216ms/step - loss: 0.1179 - acc: 0.9581 - val_loss: 0.0662 - val_acc: 0.9785
#
# Epoch 00047: val_loss improved from 0.09249 to 0.06619, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 48/100
# 155/155 [==============================] - 34s 217ms/step - loss: 0.1206 - acc: 0.9540 - val_loss: 0.1987 - val_acc: 0.9206
#
# Epoch 00048: val_loss did not improve from 0.06619
# Epoch 49/100
# 155/155 [==============================] - 34s 218ms/step - loss: 0.1295 - acc: 0.9556 - val_loss: 0.1463 - val_acc: 0.9249
#
# Epoch 00049: val_loss did not improve from 0.06619
# Epoch 50/100
# 155/155 [==============================] - 34s 221ms/step - loss: 0.0972 - acc: 0.9613 - val_loss: 0.5305 - val_acc: 0.8476
#
# Epoch 00050: val_loss did not improve from 0.06619
# Epoch 51/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1049 - acc: 0.9617 - val_loss: 0.3968 - val_acc: 0.8691
#
# Epoch 00051: val_loss did not improve from 0.06619
# Epoch 52/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1280 - acc: 0.9556 - val_loss: 0.0804 - val_acc: 0.9700
#
# Epoch 00052: val_loss did not improve from 0.06619
# Epoch 53/100
# 155/155 [==============================] - 34s 217ms/step - loss: 0.1004 - acc: 0.9641 - val_loss: 0.1303 - val_acc: 0.9399
#
# Epoch 00053: val_loss did not improve from 0.06619
# Epoch 54/100
# 155/155 [==============================] - 32s 210ms/step - loss: 0.1206 - acc: 0.9565 - val_loss: 2.0920 - val_acc: 0.7682
#
# Epoch 00054: val_loss did not improve from 0.06619
# Epoch 55/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1329 - acc: 0.9552 - val_loss: 0.1602 - val_acc: 0.9249
#
# Epoch 00055: val_loss did not improve from 0.06619
# Epoch 56/100
# 155/155 [==============================] - 34s 220ms/step - loss: 0.0921 - acc: 0.9681 - val_loss: 0.1935 - val_acc: 0.9227
#
# Epoch 00056: val_loss did not improve from 0.06619
# Epoch 57/100
# 155/155 [==============================] - 32s 209ms/step - loss: 0.0950 - acc: 0.9637 - val_loss: 0.1226 - val_acc: 0.9442
#
# Epoch 00057: val_loss did not improve from 0.06619
# Epoch 58/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1033 - acc: 0.9621 - val_loss: 0.0884 - val_acc: 0.9592
#
# Epoch 00058: val_loss did not improve from 0.06619
# Epoch 59/100
# 155/155 [==============================] - 34s 217ms/step - loss: 0.0946 - acc: 0.9706 - val_loss: 0.1187 - val_acc: 0.9549
#
# Epoch 00059: val_loss did not improve from 0.06619
# Epoch 60/100
# 155/155 [==============================] - 33s 215ms/step - loss: 0.0836 - acc: 0.9698 - val_loss: 0.2200 - val_acc: 0.9506
#
# Epoch 00060: val_loss did not improve from 0.06619
# Epoch 61/100
# 155/155 [==============================] - 33s 214ms/step - loss: 0.1158 - acc: 0.9641 - val_loss: 0.3806 - val_acc: 0.8734
#
# Epoch 00061: val_loss did not improve from 0.06619
# Epoch 62/100
# 155/155 [==============================] - 34s 217ms/step - loss: 0.0929 - acc: 0.9706 - val_loss: 0.1526 - val_acc: 0.9356
#
# Epoch 00062: val_loss did not improve from 0.06619
# Epoch 63/100
# 155/155 [==============================] - 34s 223ms/step - loss: 0.1124 - acc: 0.9593 - val_loss: 0.6958 - val_acc: 0.7618
#
# Epoch 00063: val_loss did not improve from 0.06619
# Epoch 64/100
# 155/155 [==============================] - 31s 200ms/step - loss: 0.1063 - acc: 0.9645 - val_loss: 0.1702 - val_acc: 0.9421
#
# Epoch 00064: val_loss did not improve from 0.06619
# Epoch 65/100
# 155/155 [==============================] - 29s 190ms/step - loss: 0.0920 - acc: 0.9677 - val_loss: 0.1139 - val_acc: 0.9678
#
# Epoch 00065: val_loss did not improve from 0.06619
# Epoch 66/100
# 155/155 [==============================] - 29s 189ms/step - loss: 0.1014 - acc: 0.9657 - val_loss: 0.2154 - val_acc: 0.9163
#
# Epoch 00066: val_loss did not improve from 0.06619
# Epoch 67/100
# 155/155 [==============================] - 29s 189ms/step - loss: 0.0811 - acc: 0.9714 - val_loss: 0.1345 - val_acc: 0.9506
#
# Epoch 00067: val_loss did not improve from 0.06619
# Epoch 68/100
# 155/155 [==============================] - 29s 187ms/step - loss: 0.1073 - acc: 0.9649 - val_loss: 0.0616 - val_acc: 0.9721
#
# Epoch 00068: val_loss improved from 0.06619 to 0.06157, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 69/100
# 155/155 [==============================] - 29s 187ms/step - loss: 0.0813 - acc: 0.9738 - val_loss: 0.1586 - val_acc: 0.9528
#
# Epoch 00069: val_loss did not improve from 0.06157
# Epoch 70/100
# 155/155 [==============================] - 29s 190ms/step - loss: 0.1031 - acc: 0.9605 - val_loss: 0.0945 - val_acc: 0.9700
#
# Epoch 00070: val_loss did not improve from 0.06157
# Epoch 71/100
# 155/155 [==============================] - 29s 187ms/step - loss: 0.0891 - acc: 0.9718 - val_loss: 0.0557 - val_acc: 0.9764
#
# Epoch 00071: val_loss improved from 0.06157 to 0.05574, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 72/100
# 155/155 [==============================] - 29s 188ms/step - loss: 0.1004 - acc: 0.9645 - val_loss: 1.0610 - val_acc: 0.7318
#
# Epoch 00072: val_loss did not improve from 0.05574
# Epoch 73/100
# 155/155 [==============================] - 29s 189ms/step - loss: 0.0907 - acc: 0.9669 - val_loss: 0.0491 - val_acc: 0.9871
#
# Epoch 00073: val_loss improved from 0.05574 to 0.04911, saving model to saved_model/weights.best.from_Benmark.hdf5
# Epoch 74/100
# 155/155 [==============================] - 31s 197ms/step - loss: 0.0819 - acc: 0.9718 - val_loss: 0.5239 - val_acc: 0.8412
#
# Epoch 00074: val_loss did not improve from 0.04911
# Epoch 75/100
# 155/155 [==============================] - 31s 199ms/step - loss: 0.1020 - acc: 0.9657 - val_loss: 0.1312 - val_acc: 0.9485
#
# Epoch 00075: val_loss did not improve from 0.04911
# Epoch 76/100
# 155/155 [==============================] - 31s 198ms/step - loss: 0.0880 - acc: 0.9690 - val_loss: 0.1047 - val_acc: 0.9592
#
# Epoch 00076: val_loss did not improve from 0.04911
# Epoch 77/100
# 155/155 [==============================] - 31s 201ms/step - loss: 0.0914 - acc: 0.9673 - val_loss: 0.1046 - val_acc: 0.9442
#
# Epoch 00077: val_loss did not improve from 0.04911
# Epoch 78/100
# 155/155 [==============================] - 31s 198ms/step - loss: 0.1074 - acc: 0.9661 - val_loss: 0.0504 - val_acc: 0.9850
#
# Epoch 00078: val_loss did not improve from 0.04911
# Epoch 79/100
# 155/155 [==============================] - 31s 199ms/step - loss: 0.0875 - acc: 0.9690 - val_loss: 0.2164 - val_acc: 0.9142
#
# Epoch 00079: val_loss did not improve from 0.04911
# Epoch 80/100
# 155/155 [==============================] - 31s 198ms/step - loss: 0.0814 - acc: 0.9730 - val_loss: 0.3247 - val_acc: 0.8927
#
# Epoch 00080: val_loss did not improve from 0.04911
# Epoch 81/100
# 155/155 [==============================] - 31s 199ms/step - loss: 0.0731 - acc: 0.9702 - val_loss: 2.0840 - val_acc: 0.6180
#
# Epoch 00081: val_loss did not improve from 0.04911
# Epoch 82/100
# 155/155 [==============================] - 31s 200ms/step - loss: 0.0951 - acc: 0.9718 - val_loss: 0.0903 - val_acc: 0.9592
#
# Epoch 00082: val_loss did not improve from 0.04911
# Epoch 83/100
# 155/155 [==============================] - 31s 200ms/step - loss: 0.0717 - acc: 0.9702 - val_loss: 0.0970 - val_acc: 0.9614
#
# Epoch 00083: val_loss did not improve from 0.04911
# Epoch 84/100
# 155/155 [==============================] - 31s 197ms/step - loss: 0.0904 - acc: 0.9669 - val_loss: 3.3286 - val_acc: 0.5300
#
# Epoch 00084: val_loss did not improve from 0.04911
# Epoch 85/100
# 155/155 [==============================] - 30s 194ms/step - loss: 0.0951 - acc: 0.9681 - val_loss: 0.0987 - val_acc: 0.9657
#
# Epoch 00085: val_loss did not improve from 0.04911
# Epoch 86/100
# 155/155 [==============================] - 29s 188ms/step - loss: 0.0866 - acc: 0.9710 - val_loss: 0.2604 - val_acc: 0.8841
#
# Epoch 00086: val_loss did not improve from 0.04911
# Epoch 87/100
# 155/155 [==============================] - 30s 191ms/step - loss: 0.0837 - acc: 0.9702 - val_loss: 0.3388 - val_acc: 0.8970
#
# Epoch 00087: val_loss did not improve from 0.04911
# Epoch 88/100
# 155/155 [==============================] - 29s 189ms/step - loss: 0.0848 - acc: 0.9677 - val_loss: 0.6002 - val_acc: 0.8670
#
# Epoch 00088: val_loss did not improve from 0.04911
# Epoch 89/100
# 155/155 [==============================] - 30s 194ms/step - loss: 0.0758 - acc: 0.9706 - val_loss: 0.0796 - val_acc: 0.9807
#
# Epoch 00089: val_loss did not improve from 0.04911
# Epoch 90/100
# 155/155 [==============================] - 29s 189ms/step - loss: 0.0779 - acc: 0.9714 - val_loss: 0.0787 - val_acc: 0.9785
#
# Epoch 00090: val_loss did not improve from 0.04911
# Epoch 91/100
# 155/155 [==============================] - 29s 188ms/step - loss: 0.0813 - acc: 0.9718 - val_loss: 0.1717 - val_acc: 0.9356
#
# Epoch 00091: val_loss did not improve from 0.04911
# Epoch 92/100
# 155/155 [==============================] - 29s 189ms/step - loss: 0.0723 - acc: 0.9734 - val_loss: 0.1804 - val_acc: 0.9356
#
# Epoch 00092: val_loss did not improve from 0.04911
# Epoch 93/100
# 155/155 [==============================] - 29s 188ms/step - loss: 0.0949 - acc: 0.9702 - val_loss: 0.1072 - val_acc: 0.9549
#
# Epoch 00093: val_loss did not improve from 0.04911
# Epoch 94/100
# 155/155 [==============================] - 30s 190ms/step - loss: 0.0998 - acc: 0.9726 - val_loss: 0.1107 - val_acc: 0.9571
#
# Epoch 00094: val_loss did not improve from 0.04911
# Epoch 95/100
# 155/155 [==============================] - 29s 186ms/step - loss: 0.0673 - acc: 0.9794 - val_loss: 0.1189 - val_acc: 0.9657
#
# Epoch 00095: val_loss did not improve from 0.04911
# Epoch 96/100
# 155/155 [==============================] - 29s 190ms/step - loss: 0.0865 - acc: 0.9702 - val_loss: 0.0711 - val_acc: 0.9721
#
# Epoch 00096: val_loss did not improve from 0.04911
# Epoch 97/100
# 155/155 [==============================] - 29s 189ms/step - loss: 0.0893 - acc: 0.9738 - val_loss: 0.1235 - val_acc: 0.9592
#
# Epoch 00097: val_loss did not improve from 0.04911
# Epoch 98/100
# 155/155 [==============================] - 29s 187ms/step - loss: 0.0757 - acc: 0.9710 - val_loss: 0.0927 - val_acc: 0.9635
#
# Epoch 00098: val_loss did not improve from 0.04911
# Epoch 99/100
# 155/155 [==============================] - 30s 192ms/step - loss: 0.0651 - acc: 0.9790 - val_loss: 0.0893 - val_acc: 0.9721
#
# Epoch 00099: val_loss did not improve from 0.04911
# Epoch 100/100
# 155/155 [==============================] - 30s 192ms/step - loss: 0.0720 - acc: 0.9742 - val_loss: 0.1175 - val_acc: 0.9678
#
# Epoch 00100: val_loss did not improve from 0.04911

# %%
# Evalutate the model and show loss and accuracy.
loss, acc = model.evaluate_generator(testBatch, steps=len(testBatch))

print('model performancens on balance data')
print('loss:{}'.format(loss) )
print('accuracy:{}'.format(acc))
# Out:
# model performancens on balance data
# loss:1.8760706973381105
# accuracy:0.7457264957264957

# %%
model.load_weights('saved_model/weights.best.from_benchmark.hdf5')

# %%
# Evalutate the model and show loss and accuracy.
loss, acc = model.evaluate_generator(testBatch, steps=len(testBatch))

print('model performancens on balance data')
print('loss:{}'.format(loss) )
print('accuracy:{}'.format(acc))
# Out:
# model performancens on balance data
# loss:0.9820309939163135
# accuracy:0.8141025641025641

# %%
# Making prediction on balanced test set and the original
pred = model.predict_generator(testBatch, steps=len(testBatch), verbose=True)
pred_OG = model.predict_generator(testBatch_OG, steps=len(testBatch_OG), verbose=True)
# Out:
# 468/468 [==============================] - 3s 7ms/step
# 624/624 [==============================] - 4s 7ms/step

# %%
# Applaying preprocess function to balance test set and predict.
y_true, y_pred = Preprocess_yTrue_yPred(pred, testBatch)
# Applaying preprocess function to original test set and predcit.
y_true_OG, y_pred_OG = Preprocess_yTrue_yPred(pred_OG, testBatch_OG)

# Print metrics results for balance test set.
print('Performs metrics for balance test set')
Metrics_results(y_true, y_pred)

# Print metrics results for original test set.
print('\nPerforms metrics for original test set')
Metrics_results(y_true_OG, y_pred_OG)
# Out:
# Performs metrics for balance test set
# Accuracy:0.8141025641025641
# Precision:0.9622641509433962
# Recall:0.6538461538461539
# Fbeta score:0.8071463937943555
#
# Performs metrics for original test set
# Accuracy:0.8573717948717948
# Precision:0.9503105590062112
# Recall:0.6538461538461539
# Fbeta score:0.8207493947227666
